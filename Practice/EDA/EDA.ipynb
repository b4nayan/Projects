# %%
#Import the required Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Reading & Data Types

# %%
#Read the data in pandas
inp0= pd.read_csv("/content/attribute.csv")
inp1= pd.read_csv("/content/Dress.csv")

# %% [markdown]
# You have “Attribute DataSet” which contains a column named “Price”. Choose the correct statement from the following about its data type and variable type.
# - Integer type and numerical variable
# - Object type and categorical ordinal variable
# - Object type and categorical nominal variable
# - Float type and categorical variable.

# %% [markdown]
# There is another column in “Attribute DataSet” named as “Recommendation”, choose the correct statement about its data type and variable type.
# - Integer type and categorical
# - Object type and categorical
# - Integer type and continuous numerical
# - Object type only.

# %% [markdown]
# Which of the following column do you think are of no use in “Attribute DataSet”.
# - Dress_ID
# - Price
# - Size and material
# - NeckLine
# - None of the above

# %%
# Print the information about the attributes of inp0 and inp1.
inp0['Price'].head() #Object type and categorical ordinal variable

inp0['Recommendation'].head() #Integer type and categorical

inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   O-neck   Sleeveless
# 1  1212192089   Casual      Low     0.0   Large  Summer   O-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   O-neck  Full-Sleeve
# 3   966005983    Brief  Average     4.6   Large  Spring   O-neck  Full-Sleeve
# 4   876339541     cute      Low     4.5  Medium  Summer   O-neck    Butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation   Summer  \
# 0         cotton    Chiffon     ruffles       animal               1  17822.0
# 1     microfiber    Chiffon     ruffles       animal               0  10240.0
# 2       polyster    Chiffon     ruffles        print               0     51.0
# 3           silk    Chiffon  embroidary        print               1   9168.0
# 4  chiffonfabric    Chiffon         bow          dot               0  10320.0
#
#     Winter  Spring   Autumn
# ...

# %% [markdown]
# ### Fixing the Rows and Columns

# %% [markdown]
# As you can see, there is a column in “Attribute Dataset” named as ‘Size’. This column contains the values in abbreviation format. Write a code in Python to convert the followings:
#
# - M into  “Medium”
# - L into  “Large”
# - XL into “Extra large”
# - free into “Free”
# - S, s & small into “Small”.
#
# Now once you are done with changes in the dataset, what is the value of the lowest percentage, the highest percentage and the percentage of Small size categories in the column named “Size”?

# %%
# Column fixing, correcting size abbreviation. count the percentage of each size category in "Size" column.
print(inp0['Size'].value_counts())
size_mapping = {
    'm': 'Medium',
    'l': 'Large',
    'xl': 'Extra large',
    'free': 'Free',
    's': 'Small',
    'small': 'Small'
}

# Convert Size column values to lowercase and map
inp0['Size'] = inp0['Size'].str.lower().map(size_mapping).fillna(inp0['Size'])
for every in inp0['Size'].value_counts():
  print(f"{every}",every/len(inp0['Size'])*100)

per=inp0['Size'].value_counts(normalize=True)
per*100
# Out:
# Size
# Medium         170
# Free           162
# Large           90
# Small           36
# Extra large     14
# Name: count, dtype: int64
# 170 36.016949152542374
# 162 34.32203389830508
# 90 19.06779661016949
# 36 7.627118644067797
# 14 2.9661016949152543
# Size
# Medium         36.016949
# Free           34.322034
# Large          19.067797
# Small           7.627119
# Extra large     2.966102
# Name: proportion, dtype: float64

# %%
# Print the value counts of each category in "Size" column.
inp0['Size'].value_counts()
# Out:
# Size
# Medium         171
# Free           165
# Large           93
# Small           36
# Extra large     14
# Name: count, dtype: int64

# %% [markdown]
# ### Impute/Remove Missing values

# %%
# Print the null count of each variables of inp0 and inp1.
inp0.isna().sum(), inp1.isna().sum()
# Out:
# (Dress_ID            0
#  Style               0
#  Price               2
#  Rating              0
#  Size                0
#  Season              2
#  NeckLine            3
#  SleeveLength        2
#  Material          119
#  FabricType        256
#  Decoration        224
#  Pattern Type      102
#  Recommendation      0
#  dtype: int64,
#  Dress_ID        0
#  29-08-2013      0
#  31-08-2013      0
#  09-02-2013      0
#  09-04-2013      0
#  09-06-2013      0
#  09-08-2013      0
#  09-10-2013      0
#  09-12-2013      0
#  14-09-2013      0
#  16-09-2013      0
#  18-09-2013      0
#  20-09-2013      0
#  22-09-2013      0
#  24-09-2013      0
#  26-09-2013    222
#  28-09-2013      0
#  30-09-2013    257
#  10-02-2013    259
#  10-04-2013    258
#  10-06-2013      0
#  10-08-2013    255
#  10-10-2013    255
#  10-12-2013      0
#  dtype: int64)

# %% [markdown]
# You are given another dataset named “Dress Sales”. Now if you observe the datatypes of the columns using ‘inp1.info()’ command, you can identify that there are certain columns defined as object data type though they primarily consist of numeric data.
#
# Now if you try and convert these object data type columns into numeric data type(float), you will come across an error message. Try to correct this error.

# %%
# Print the data types information of inp1 i.e. "Dress Sales" data.
import pandas as pd
inp1= pd.read_csv("/content/Dress.csv",index_col=0)
inp1.head()
# Out:
#               29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# Dress_ID
# 1.006033e+09        2114        2274        2491        2660        2727
# 1.212192e+09         151         275         570         750         813
# 1.190381e+09           6           7           7           7           8
# 9.660060e+08        1005        1128        1326        1455        1507
# 8.763395e+08         996        1175        1304        1396        1432
#
#               09-08-2013  09-10-2013 09-12-2013 14-09-2013 16-09-2013  ...  \
# Dress_ID                                                               ...
# 1.006033e+09        2887        2930       3119       3204       3277  ...
# 1.212192e+09        1066        1164       1558       1756       1878  ...
# 1.190381e+09           8           9         10         10         10  ...
# 9.660060e+08        1621        1637       1723       1746       1783  ...
# ...

# %%
inp1.isna().sum() #18-09-2013
# Out:
# 29-08-2013      0
# 31-08-2013      0
# 09-02-2013      0
# 09-04-2013      0
# 09-06-2013      0
# 09-08-2013      0
# 09-10-2013      0
# 09-12-2013      0
# 14-09-2013      0
# 16-09-2013      0
# 18-09-2013      0
# 20-09-2013      0
# 22-09-2013      0
# 24-09-2013      0
# 26-09-2013    222
# 28-09-2013      0
# 30-09-2013    257
# 10-02-2013    259
# 10-04-2013    258
# 10-06-2013      0
# 10-08-2013    255
# 10-10-2013    255
# 10-12-2013      0
# dtype: int64

# %%
# Try to convert the object type into float type of data. YOU GET ERROR MESSAGE.
col=inp1.select_dtypes(include=['object']).columns
inp1[col]=inp1[col].apply(pd.to_numeric, errors='coerce')

# %%
# Do the required changes in the "Dress Sales" data set to get null values on string values.
inp1.isna().sum()
# Out:
# 29-08-2013      0
# 31-08-2013      0
# 09-02-2013      0
# 09-04-2013      0
# 09-06-2013      0
# 09-08-2013      0
# 09-10-2013      0
# 09-12-2013      1
# 14-09-2013      1
# 16-09-2013      1
# 18-09-2013      1
# 20-09-2013      1
# 22-09-2013      1
# 24-09-2013      0
# 26-09-2013    222
# 28-09-2013      0
# 30-09-2013    257
# 10-02-2013    259
# 10-04-2013    258
# 10-06-2013      0
# 10-08-2013    255
# 10-10-2013    255
# 10-12-2013      0
# dtype: int64

# %%
# Convert the object type columns in "Dress Sales" into float type of data type.

# %% [markdown]
# When you see the null counts in “Dress Sales” dataset after performing all the operations that have been mentioned in jupyter notebook, you will find that there are some columns in “Dress Sales” data where there are more than 40% of missing values. Based on your understanding of dealing with missing values do the following steps.

# %%
# Print the null percetange of each column of inp1.
for every in inp1.columns:
  print(f"The column name is {every} the percent is : {round((inp1[every].isnull().sum() / len(inp1[every])) * 100,2)}")
# Out:
# The column name is 29-08-2013 the percent is : 0.0
# The column name is 31-08-2013 the percent is : 0.0
# The column name is 09-02-2013 the percent is : 0.0
# The column name is 09-04-2013 the percent is : 0.0
# The column name is 09-06-2013 the percent is : 0.0
# The column name is 09-08-2013 the percent is : 0.0
# The column name is 09-10-2013 the percent is : 0.0
# The column name is 09-12-2013 the percent is : 0.21
# The column name is 14-09-2013 the percent is : 0.21
# The column name is 16-09-2013 the percent is : 0.21
# The column name is 18-09-2013 the percent is : 0.21
# The column name is 20-09-2013 the percent is : 0.21
# The column name is 22-09-2013 the percent is : 0.21
# The column name is 24-09-2013 the percent is : 0.0
# The column name is 26-09-2013 the percent is : 46.35
# The column name is 28-09-2013 the percent is : 0.0
# The column name is 30-09-2013 the percent is : 53.65
# The column name is 10-02-2013 the percent is : 54.07
# ...

# %%
# Drop the columns in "Dress Sales" which have more than 40% of missing values.
for every in inp1.columns:
  if round((inp1[every].isnull().sum() / len(inp1[every])) * 100,2)>40:
    inp1.drop(every, axis=1, inplace=True)
inp1.columns
# Out:
# Index(['29-08-2013', '31-08-2013', '09-02-2013', '09-04-2013', '09-06-2013',
#        '09-08-2013', '09-10-2013', '09-12-2013', '14-09-2013', '16-09-2013',
#        '18-09-2013', '20-09-2013', '22-09-2013', '24-09-2013', '28-09-2013',
#        '10-06-2013', '10-12-2013'],
#       dtype='object')

# %% [markdown]
# You should categorise the dates into seasons in “Dress Sales” data to simplify the analysis according to the following criteria:
# - June, July and August: Summer.
# - September, October and November: Autumn.
# - December, January and February: WInter.
# - March, April and May: Spring.

# %%
# Create the four seasons columns in inp1, according to the above criteria.
inp1=pd.read_csv('Dress.csv')
df=inp1.copy()


from collections import defaultdict

def get_season(month):
    if month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Autumn'
    elif month in [12, 1, 2]:
        return 'Winter'
    else:
        return 'Spring'

date_columns = [col for col in df.columns if col != 'Dress_ID']

season_columns = defaultdict(list)


for col in date_columns:
    try:
        date = pd.to_datetime(col, format='%d-%m-%Y')
        season = get_season(date.month)
        season_columns[season].append(col)
    except Exception as e:
        print(f"Skipping column {col}: {e}")
print(date,season,season_columns)

df[date_columns] = df[date_columns].apply(pd.to_numeric, errors='coerce')


seasonal_sales_cleaned = pd.DataFrame()
seasonal_sales_cleaned['Dress_ID'] = df['Dress_ID']

for season, cols in season_columns.items():
    seasonal_sales_cleaned[season] = df[cols].sum(axis=1)
seasonal_sales_cleaned.head()
# Out:
# 2013-12-10 00:00:00 Winter defaultdict(<class 'list'>, {'Summer': ['29-08-2013', '31-08-2013', '09-06-2013', '09-08-2013', '10-06-2013', '10-08-2013'], 'Winter': ['09-02-2013', '09-12-2013', '10-02-2013', '10-12-2013'], 'Spring': ['09-04-2013', '10-04-2013'], 'Autumn': ['09-10-2013', '14-09-2013', '16-09-2013', '18-09-2013', '20-09-2013', '22-09-2013', '24-09-2013', '26-09-2013', '28-09-2013', '30-09-2013', '10-10-2013']})
#        Dress_ID   Summer   Winter  Spring   Autumn
# 0  1.006033e+09  17822.0  13453.0  6492.0  38212.0
# 1  1.212192e+09  10240.0   9880.0  4404.0  27732.0
# 2  1.190381e+09     51.0     39.0    18.0    115.0
# 3  9.660060e+08   9168.0   6941.0  3396.0  20186.0
# 4  8.763395e+08  10320.0   8065.0  3855.0  21837.0

# %%
# calculate the sum of sales in each seasons in inp1 i.e. "Dress Sales".
for every in seasonal_sales_cleaned.columns:
  if every=='Dress_ID':
    continue
  else:
    print(f"The column name is {every} the sum is : {seasonal_sales_cleaned[every].sum()}")
# Out:
# The column name is Summer the sum is : 749797.0
# The column name is Winter the sum is : 529149.0
# The column name is Spring the sum is : 199084.0
# The column name is Autumn the sum is : 1551540.0

# %% [markdown]
# Now let's merge inp1 with inp0 with left join manner, so that the information of inp0 should remain intact.

# %%
# Merge inp0 with inp1 into inp0. this is also called left merge.
inp0 = pd.merge(left=inp0,right=inp1, how='left', left_on='Dress_ID', right_on='Dress_ID')
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  ... 24-09-2013 26-09-2013  28-09-2013  \
# 0            NaN    chiffon  ...       3554     3624.0        3706
# 1     microfiber        NaN  ...       2710     2942.0        3258
# 2       polyster        NaN  ...         11       11.0          11
# 3           silk    chiffon  ...       1878     1892.0        1914
# 4  chiffonfabric    chiffon  ...       2032     2156.0        2252
#
#    30-09-2013  10-02-2013  10-04-2013  10-06-2013  10-08-2013  10-10-2013  \
# ...

# %%
# Now Drop the Date columns from inp0 as it is already combined into four seasons.
inp0.drop(inp0.loc[:,'29-08-2013':'10-12-2013'].columns, axis= 1, inplace= True)
inp0.isnull().sum()
inp0=pd.merge(left=inp0,right=seasonal_sales_cleaned, how='left', left_on='Dress_ID', right_on='Dress_ID')
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation   Summer  \
# 0            NaN    chiffon     ruffles       animal               1  17822.0
# 1     microfiber        NaN     ruffles       animal               0  10240.0
# 2       polyster        NaN         NaN        print               0     51.0
# 3           silk    chiffon  embroidary        print               1   9168.0
# 4  chiffonfabric    chiffon         bow          dot               0  10320.0
#
#     Winter  Spring   Autumn
# ...

# %% [markdown]
# Print the null count of inp0 to get the idea about the missing values in data set.

# %%
# Print the null count of each columns in inp0 dataframe i.e. combined data frame of inp0 and inp1 without date columns.
inp0.isna().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# Summer              0
# Winter              0
# Spring              0
# Autumn              0
# dtype: int64

# %% [markdown]
# You can see that there are two types of variables one with a large number of missing values and another is very less number of missing values. These two columns can be categorized as:
#
# Type-1: Missing values are very less (around 2 or 3 missing values): Price, Season, NeckLine, SleeveLength, Winter and Autumn.
#
# Type-2: Missing values are large in numbers (more than 15%): Material, FabricType, Decoration and Pattern Type.

# %%
# Deal with the missing values of Type-1 columns: Price, Season, NeckLine, SleeveLength, Winter and Autumn.
inp0 = inp0.dropna(subset=['Price', 'Season', 'NeckLine', 'SleeveLength', 'Winter', 'Autumn'])

for col in ['Material', 'FabricType', 'Decoration', 'Pattern Type']:
    if col=='Decoration':
      inp0[col] = inp0[col].ffill()
    else:
      inp0[col].fillna(inp0[col].mode()[0], inplace=True)
print(inp0.isna().sum())
# Out:
# Dress_ID          0
# Style             0
# Price             0
# Rating            0
# Size              0
# Season            0
# NeckLine          0
# SleeveLength      0
# Material          0
# FabricType        0
# Decoration        0
# Pattern Type      0
# Recommendation    0
# Summer            0
# Winter            0
# Spring            0
# Autumn            0
# dtype: int64
# <ipython-input-20-8d47f68d3d6f>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
# Deal with the missing values for Type-2 columns: Material, FabricType, Decoration and Pattern Type.

# %% [markdown]
# ### Standardise value

# %% [markdown]
# In the given dataset, there are certain discrepancies with the categorical names such as irregular spellings. Choose the correct option of columns with irregular categories and update them.
#
# - Season, NeckLine
# - Price, Material
# - fabricType, Decoration
# - Season, SleeveLength

# %%
#correcting the spellings.
print(inp0['Season'].unique())
inp0['Season'] = inp0['Season'].str.strip().str.capitalize()
print(inp0['Season'].unique())

'''
print(inp0['NeckLine'].unique())
print(inp0['Price'].unique())
print(inp0['Material'].unique())
print(inp0['FabricType'].unique())
print(inp0['Decoration'].unique())
print(inp0['SleeveLength'].unique())'''
# Out:
# ['Summer' 'Automn' 'Spring' 'Winter' 'spring' 'winter' 'Autumn']
# ['Summer' 'Automn' 'Spring' 'Winter' 'Autumn']
# <ipython-input-22-14002f970c28>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inp0['Season'] = inp0['Season'].str.strip().str.capitalize()
# "\nprint(inp0['NeckLine'].unique())\nprint(inp0['Price'].unique())\nprint(inp0['Material'].unique())\nprint(inp0['FabricType'].unique())\nprint(inp0['Decoration'].unique())\nprint(inp0['SleeveLength'].unique())"

# %%
print(inp0['Decoration'].unique())
# Out:
# ['ruffles' 'embroidary' 'bow' 'beading' 'lace' 'sashes' 'hollowout'
#  'pockets' 'sequined' 'applique' 'button' 'Tiered' 'rivet' 'feathers'
#  'flowers' 'pearls' 'crystal' 'ruched' 'draped' 'tassel' 'plain'
#  'cascading' 'none']

# %%
print(inp0['NeckLine'].unique())
inp0['NeckLine'] = inp0['NeckLine'].str.strip().str.capitalize()
print(inp0['NeckLine'].unique())
# Out:
# ['o-neck' 'v-neck' 'boat-neck' 'peterpan-collor' 'ruffled'
#  'turndowncollor' 'slash-neck' 'mandarin-collor' 'open' 'sqare-collor'
#  'Sweetheart' 'sweetheart' 'Scoop' 'halter' 'backless' 'bowneck']
# ['O-neck' 'V-neck' 'Boat-neck' 'Peterpan-collor' 'Ruffled'
#  'Turndowncollor' 'Slash-neck' 'Mandarin-collor' 'Open' 'Sqare-collor'
#  'Sweetheart' 'Scoop' 'Halter' 'Backless' 'Bowneck']
# <ipython-input-24-c22fe744b85f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inp0['NeckLine'] = inp0['NeckLine'].str.strip().str.capitalize()

# %%
print(inp0['SleeveLength'].unique())
fix_map = {
    'sleevless': 'Sleeveless',
    'sleeevless': 'Sleeveless',
    'sleveless': 'Sleeveless',
    'sleeveless': 'Sleeveless',

    'halfsleeve': 'Half-Sleeve',
    'half': 'Half-Sleeve',

    'capsleeves': 'Cap-Sleeve',
    'cap-sleeves': 'Cap-Sleeve',

    'threequarter': 'Three-Quarter',
    'threequater': 'Three-Quarter',
    'thressqatar': 'Three-Quarter',

    'turndowncollor': 'Turn-Down Collar',
    'urndowncollor': 'Turn-Down Collar',

    'full': 'Full-Sleeve',
    'short': 'Short-Sleeve',
    'Petal': 'Petal',
    'butterfly': 'Butterfly'
}
inp0['SleeveLength'] = inp0['SleeveLength'].replace(fix_map)
print(inp0['SleeveLength'].unique())
# Out:
# ['sleevless' 'Petal' 'full' 'butterfly' 'short' 'threequarter'
#  'halfsleeve' 'cap-sleeves' 'turndowncollor' 'threequater' 'capsleeves'
#  'sleeveless' 'sleeevless' 'half' 'urndowncollor' 'thressqatar'
#  'sleveless']
# ['Sleeveless' 'Petal' 'Full-Sleeve' 'Butterfly' 'Short-Sleeve'
#  'Three-Quarter' 'Half-Sleeve' 'Cap-Sleeve' 'Turn-Down Collar']
# <ipython-input-25-1d47ac6df25a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inp0['SleeveLength'] = inp0['SleeveLength'].replace(fix_map)

# %%
print(inp0['FabricType'].unique())
# Out:
# ['chiffon' 'broadcloth' 'jersey' 'other' 'batik' 'satin' 'flannael'
#  'worsted' 'woolen' 'poplin' 'dobby' 'knitting' 'flannel' 'tulle' 'sattin'
#  'organza' 'lace' 'Corduroy' 'wollen' 'knitted' 'shiffon' 'terry']

# %%
#correcting the Spellings.
fabric_map = {
    'chiffon': 'Chiffon',
    'shiffon': 'Chiffon',

    'satin': 'Satin',
    'sattin': 'Satin',

    'flannael': 'Flannel',
    'flannel': 'Flannel',

    'woolen': 'Wool',
    'wollen': 'Wool',

    'knitted': 'Knitted',
    'knitting': 'Knitted',

    'Corduroy': 'Corduroy',

    # Leave these as-is, just capitalize
    'broadcloth': 'Broadcloth',
    'jersey': 'Jersey',
    'other': 'Other',
    'batik': 'Batik',
    'worsted': 'Worsted',
    'poplin': 'Poplin',
    'dobby': 'Dobby',
    'tulle': 'Tulle',
    'organza': 'Organza',
    'lace': 'Lace',
    'terry': 'Terry'
}


inp0['FabricType'] = inp0['FabricType'].replace(fabric_map)
print(inp0['FabricType'].unique())
# Out:
# ['Chiffon' 'Broadcloth' 'Jersey' 'Other' 'Batik' 'Satin' 'Flannel'
#  'Worsted' 'Wool' 'Poplin' 'Dobby' 'Knitted' 'Tulle' 'Organza' 'Lace'
#  'Corduroy' 'Terry']
# <ipython-input-27-01642e217d13>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inp0['FabricType'] = inp0['FabricType'].replace(fabric_map)

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical Unordered Univariate Analysis

# %% [markdown]
# There is a column named ‘Style’ in ‘Attribute Dataset’ which consists of the different style categories of the women apparels. Certain categories whose total sale is less than 50000 across all the seasons is considered under one single category as ‘Others’.

# %% [markdown]
# Which of the following categories in ‘Style’ column can be grouped into ‘Others’ category? and perform the grouping operation in the notebook for further analysis.
# - Flare, fashion
# - Novelty, bohemian
# - OL, fashion, work
# - Novelty, fashion, Flare

# %%
# Group "Style" categories into "Others" which have less than 50000 sales across all the seasons.
sales=inp0.groupby('Style')[['Summer','Spring','Autumn','Winter']].sum()
print(sales)
list1=list()
for every in sales.index:
  if sales.loc[every].sum()<50000:
    list1.append(every)
print(list1)
for every in list1:
  inp0.loc[inp0['Style']==every,'Style']='Others'
inp0['Style'].unique()
# Out:
#             Summer   Spring    Autumn    Winter
# Style
# Brief      40118.0  10273.0   79938.0   27790.0
# Casual    301843.0  78428.0  630588.0  209935.0
# Flare        668.0    281.0    1776.0     611.0
# Novelty     3432.0   1074.0    9314.0    2991.0
# OL            87.0     38.0     228.0      76.0
# Sexy      128887.0  34546.0  264535.0   92072.0
# bohemian   16737.0   4403.0   39880.0   12351.0
# cute      111232.0  32708.0  217615.0   76685.0
# fashion       91.0     19.0     242.0      74.0
# party      37331.0   9747.0   82920.0   26277.0
# sexy       27270.0   7214.0   55613.0   20602.0
# vintage    51658.0  13312.0  107251.0   38103.0
# work       25665.0   5873.0   49428.0   17830.0
# ['Flare', 'Novelty', 'OL', 'fashion']
# array(['Sexy', 'Casual', 'vintage', 'Brief', 'cute', 'bohemian', 'Others',
#        'party', 'sexy', 'work'], dtype=object)

# %% [markdown]
# What is the percentage of “cute” and “Others” category in “Style” column in “Attribute DataSet” respectively?
# - 46%, 5%
# - 9%, 2.1%
# - 2.1%, 5%
# - 13.8%, 9%

# %%
# Calculate the percentage of each categories in the "Style" variable.
total_rows = len(inp0)

# Count the occurrences of 'cute' and 'Others' in the 'Style' column
cute_count = inp0[inp0['Style'] == 'cute'].shape[0]
others_count = inp0[inp0['Style'] == 'Others'].shape[0]

# Calculate the percentages
cute_percentage = (cute_count / total_rows) * 100
others_percentage = (others_count / total_rows) * 100
cute_percentage,others_percentage
# Out:
# (9.110169491525424, 2.11864406779661)

# %% [markdown]
# Similarly Club Neckline, SLeeve length categories into "Others" which have less than 50000 sales across all the seasons.

# %%
# Group "Neckline" categories into "Others" which have less than 50000 sales across all the seasons.
sales=inp0.groupby('NeckLine')[['Summer','Spring','Autumn','Winter']].sum()
print(sales)
list1=list()
for every in sales.index:
  if sales.loc[every].sum()<50000:
    list1.append(every)
print(list1)
for every in list1:
  inp0.loc[inp0['NeckLine']==every,'NeckLine']='Others'
inp0['NeckLine'].unique()
# Out:
#                    Summer    Spring    Autumn    Winter
# NeckLine
# Backless            600.0     190.0    1690.0     408.0
# Boat-neck         13892.0    3728.0   32109.0   10203.0
# Bowneck            4872.0    1599.0   13181.0    3621.0
# Halter              505.0     151.0    1336.0     363.0
# Mandarin-collor      87.0      38.0     228.0      76.0
# O-neck           473367.0  126840.0  984967.0  337129.0
# Open               2092.0     456.0    3805.0    1381.0
# Peterpan-collor    5910.0    1611.0   10412.0    3771.0
# Ruffled           41489.0   13516.0   74249.0   26673.0
# Scoop               753.0     291.0    2076.0     569.0
# Slash-neck        17436.0    4672.0   39728.0   12339.0
# Sqare-collor       8459.0    1750.0   16503.0    5683.0
# Sweetheart         4545.0    1962.0   12499.0    3534.0
# Turndowncollor    18267.0    4191.0   36996.0   13219.0
# V-neck           152745.0   36921.0  309549.0  106428.0
# ...

# %%
sales=inp0.groupby('Style')[['Summer','Spring','Autumn','Winter']].sum()
print(sales)
list1=list()
for every in sales.index:
  if sales.loc[every].sum()<50000:
    list1.append(every)
print(list1)
# Out:
#             Summer   Spring    Autumn    Winter
# Style
# Brief      40118.0  10273.0   79938.0   27790.0
# Casual    301843.0  78428.0  630588.0  209935.0
# Others      4278.0   1412.0   11560.0    3752.0
# Sexy      128887.0  34546.0  264535.0   92072.0
# bohemian   16737.0   4403.0   39880.0   12351.0
# cute      111232.0  32708.0  217615.0   76685.0
# party      37331.0   9747.0   82920.0   26277.0
# sexy       27270.0   7214.0   55613.0   20602.0
# vintage    51658.0  13312.0  107251.0   38103.0
# work       25665.0   5873.0   49428.0   17830.0
# ['Others']

# %%
# Group "Sleeve length" categories into "Others" which have less than 50000 sales across all the seasons.
sales=inp0.groupby('SleeveLength')[['Summer','Spring','Autumn','Winter']].sum()
print(sales)
list1=list()
for every in sales.index:
  if sales.loc[every].sum()<50000:
    list1.append(every)
print(list1)
for every in list1:
  inp0.loc[inp0['SleeveLength']==every,'SleeveLength']='Others'
inp0['SleeveLength'].unique()
# Out:
#                     Summer   Spring    Autumn    Winter
# SleeveLength
# Butterfly          10320.0   3855.0   21837.0    8065.0
# Cap-Sleeve          3290.0   1319.0    9001.0    2360.0
# Full-Sleeve       130269.0  34623.0  270620.0   91568.0
# Half-Sleeve        58429.0  15084.0  114841.0   39017.0
# Petal              10240.0   4404.0   27732.0    9880.0
# Short-Sleeve      202579.0  53350.0  398883.0  140355.0
# Sleeveless        261432.0  68768.0  566855.0  188498.0
# Three-Quarter      67606.0  16242.0  127184.0   44915.0
# Turn-Down Collar     854.0    271.0    2375.0     739.0
# ['Butterfly', 'Cap-Sleeve', 'Turn-Down Collar']
# array(['Sleeveless', 'Petal', 'Full-Sleeve', 'Others', 'Short-Sleeve',
#        'Three-Quarter', 'Half-Sleeve'], dtype=object)

# %% [markdown]
# Club material, fabrictype, patterntype and decoration categories into "Others" which have less than 25000 sales across all the seasons

# %%
# Group "material" categories into "Others" which have less than 25000 sales across all the seasons.
sales=inp0.groupby('Material')[['Summer','Spring','Autumn','Winter']].sum()
print(sales)
list1=list()
for every in sales.index:
  if sales.loc[every].sum()<25000:
    list1.append(every)
print(list1)
for every in list1:
  inp0.loc[inp0['Material']==every,'Material']='Others'
inp0['Material'].unique()
# Out:
#                  Summer    Spring    Autumn    Winter
# Material
# acrylic          3440.0    1357.0    8430.0    2560.0
# cashmere         1454.0     315.0    2930.0     988.0
# chiffonfabric  101504.0   29313.0  191906.0   66377.0
# cotton         392454.0  105808.0  819344.0  280085.0
# lace             1773.0     350.0    3046.0    1127.0
# linen            5385.0    1088.0   11173.0    3750.0
# lycra            3426.0     714.0    7606.0    2527.0
# microfiber      10562.0    4562.0   28637.0   10128.0
# milksilk         9453.0    2458.0   19260.0    6661.0
# mix             18516.0    4083.0   37232.0   13532.0
# modal             181.0      65.0     347.0     128.0
# model              76.0      32.0     214.0      67.0
# nylon            6928.0    2044.0   17414.0    5112.0
# other            1357.0     489.0    3605.0    1075.0
# polyster       134996.0   30547.0  273088.0   93397.0
# rayon           18163.0    4069.0   33262.0   11643.0
# ...

# %%
# Group "fabric type" categories into "Others" which have less than 25000 sales across all the seasons.
sales=inp0.groupby('FabricType')[['Summer','Spring','Autumn','Winter']].sum()
print(sales)
list1=list()
for every in sales.index:
  if sales.loc[every].sum()<25000:
    list1.append(every)
print(list1)
for every in list1:
  inp0.loc[inp0['FabricType']==every,'FabricType']='Others'
inp0['FabricType'].unique()
# Out:
#               Summer    Spring     Autumn    Winter
# FabricType
# Batik          864.0      98.0     2322.0     854.0
# Broadcloth   32068.0    7439.0    66244.0   22837.0
# Chiffon     630516.0  168355.0  1306689.0  443822.0
# Corduroy      2947.0    1343.0     8210.0    2291.0
# Dobby          744.0     146.0     1374.0     497.0
# Flannel       6040.0    1175.0    10457.0    3896.0
# Jersey       37165.0   10797.0    72081.0   25717.0
# Knitted         16.0       7.0       41.0      13.0
# Lace           446.0     141.0     1186.0     309.0
# Organza        215.0     106.0      607.0     164.0
# Other          468.0     207.0     1186.0     458.0
# Poplin         442.0     191.0     1104.0     345.0
# Satin         4753.0    1178.0    12573.0    4828.0
# Terry          112.0      54.0      298.0      88.0
# Tulle          440.0     137.0     1234.0     314.0
# Wool          5349.0    1126.0     9193.0    3196.0
# Worsted      22434.0    5416.0    44529.0   15768.0
# ...

# %%
# Group "patern type" categories into "Others" which have less than 25000 sales across all the seasons.
sales=inp0.groupby('Pattern Type')[['Summer','Spring','Autumn','Winter']].sum()
print(sales)
list1=list()
for every in sales.index:
  if sales.loc[every].sum()<25000:
    list1.append(every)
print(list1)
for every in list1:
  inp0.loc[inp0['Pattern Type']==every,'Pattern Type']='Others'
inp0['Pattern Type'].unique()
# Out:
#                 Summer    Spring    Autumn    Winter
# Pattern Type
# animal         66503.0   21870.0  144263.0   51307.0
# character        993.0     176.0    1841.0     728.0
# dot            78958.0   22836.0  143690.0   51912.0
# floral          2807.0     534.0    5340.0    1933.0
# geometric      33031.0    6615.0   55370.0   20651.0
# leapord          623.0     124.0    1732.0     538.0
# leopard         6912.0    1164.0   12481.0    5022.0
# none            1825.0     891.0    4824.0    1439.0
# patchwork      48874.0   10678.0  103059.0   33948.0
# plaid            398.0     111.0     898.0     302.0
# print         112586.0   28195.0  230606.0   79825.0
# solid         374313.0  100824.0  797815.0  265108.0
# splice          1042.0     270.0    2990.0     810.0
# striped        16154.0    3628.0   34419.0   11874.0
# ['character', 'floral', 'leapord', 'none', 'plaid', 'splice']
# array(['animal', 'print', 'dot', 'solid', 'patchwork', 'striped',
# ...

# %%
# Group "decoration" categories into "Others" which have less than 25000 sales across all the seasons.
sales=inp0.groupby('Decoration')[['Summer','Spring','Autumn','Winter']].sum()
print(sales)
list1=list()
for every in sales.index:
  if sales.loc[every].sum()<25000:
    list1.append(every)
print(list1)
for every in list1:
  inp0.loc[inp0['Decoration']==every,'Decoration']='Others'
inp0['Decoration'].unique()
# Out:
#               Summer   Spring    Autumn    Winter
# Decoration
# Tiered        6366.0   1268.0   10603.0    3910.0
# applique     31444.0   7405.0   67233.0   23037.0
# beading      42230.0  11412.0   85185.0   29714.0
# bow         120346.0  33760.0  230490.0   79060.0
# button       12236.0   2321.0   24887.0    8845.0
# cascading       61.0     26.0     178.0      52.0
# crystal       2001.0    626.0    5560.0    1532.0
# draped        2414.0   1034.0    6279.0    1747.0
# embroidary   26851.0   6607.0   52860.0   19341.0
# feathers        20.0      9.0      52.0      17.0
# flowers       2589.0    605.0    4832.0    1732.0
# hollowout    33649.0   7931.0   78172.0   26010.0
# lace        200052.0  53738.0  409645.0  141446.0
# none          3171.0   1580.0    8649.0    2228.0
# pearls          17.0      8.0      50.0      15.0
# plain         1245.0    375.0    3531.0     936.0
# pockets       6845.0   2360.0   14490.0    5085.0
# ...

# %% [markdown]
# ### Caregorical Ordered Univariate Analysis

# %% [markdown]
# Which of the following is an unordered variable in “Attribute DataSet”.
# - Style
# - Price
# - Season
# - Size

# %% [markdown]
# ### Numerical variable Univariate analysis:

# %% [markdown]
# What is the approximate difference between the maximum value and 75th percentile in “Autumn” column.
# - Approx 54000
# - Approx 55000
# - Approx 52000
# - Approx 50000

# %%
# Describe the numerical variale: "Autumn".
#style
inp0['Autumn'].max()- inp0['Autumn'].quantile(0.75)
# Out:
# np.float64(70913.75)

# %%
# plot the boxplot of "Autumn" column.
import seaborn as sns
sns.boxplot(inp0['Autumn'])
# Out:
# <Axes: ylabel='Autumn'>

# %% [markdown]
# Which of the following season has the highest difference between the maximum value and 99th quantile of sales?
# - Winter
# - Summer
# - Spring
# - Autumn

# %%
# Find the maximum and 99th percentile of Winter season.
inp0['Winter'].max()- inp0['Winter'].quantile(0.99)
# Out:
# np.float64(16791.55)

# %%
# Find the maximum and 99th percentile of Summer season.
inp0['Summer'].max()- inp0['Summer'].quantile(0.99)
# Out:
# np.float64(26591.219999999947)

# %%
# Find the maximum and 99th percentile of Spring season.
inp0['Spring'].max()- inp0['Spring'].quantile(0.99)
# Out:
# np.float64(9205.719999999998)

# %%
# Find the maximum and 99th percentile of Autumn season.
inp0['Autumn'].max()- inp0['Autumn'].quantile(0.99)
# Out:
# np.float64(46709.409999999996)

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical- Categorical analysis

# %% [markdown]
# Which of the following “Price” category has the lowest average value of rating?
# - very-high
# - Medium
# - Low
# - High

# %%
# Find the Mean of Ratings for each Price category.
rate=inp0.groupby('Price')[['Rating']].mean()
rate
# Out:
#              Rating
# Price
# Average    3.455042
# High       2.914286
# Low        3.731481
# Medium     3.156667
# very-high  3.123810

# %% [markdown]
# What is the median of the rating of “vintage” category in Style column?
# - 4.6
# - 4.7
# - 4.55
# - 0.00

# %%
# Find the median of Ratings for each Style category.
med=inp0.groupby('Style')[['Rating']].median()
med
# Out:
#           Rating
# Style
# Brief        4.6
# Casual       4.6
# Others       0.0
# Sexy         4.6
# bohemian     4.6
# cute         4.6
# party        4.7
# sexy         4.5
# vintage      4.6
# work         4.7

# %% [markdown]
# Which of the following season has the highest average value of sale for “Recommendation” value equals to 1.
# - Summer
# - Spring
# - Autumn
# - Winter

# %%
# Summer sale vs Recommendation.
sales=inp0.groupby('Recommendation')[['Summer']].mean()
sales
# Out:
#                      Summer
# Recommendation
# 0               1516.139706
# 1               1663.145000

# %%
# Spring sale vs Recommendation.
sales=inp0.groupby('Recommendation')[['Spring']].mean()
sales
# Out:
#                     Spring
# Recommendation
# 0               374.841912
# 1               479.795000

# %%
# Autumn sale vs Recommendation.
sales=inp0.groupby('Recommendation')[['Autumn']].mean()
sales
# Out:
#                      Autumn
# Recommendation
# 0               3111.238971
# 1               3465.355000

# %%
# Winter sale vs Recommendation.
sales=inp0.groupby('Recommendation')[['Winter']].mean()
sales
# Out:
#                      Winter
# Recommendation
# 0               1062.301471
# 1               1182.255000

# %% [markdown]
# ### Categorical categorical bivariate analysis

# %% [markdown]
# Which of the following size categories has the highest positive recommendations?
# - Medium and extra large
# - Extra large and small
# - Free and small
# - Free and medium

# %%
# Size vs Recommendation.
sales=inp0.groupby('Recommendation')[['Size']].value_counts()
sales
#free and medium
# Out:
# Recommendation  Size
# 0               Medium         94
#                 Free           88
#                 Large          57
#                 Small          23
#                 Extra large    10
# 1               Medium         76
#                 Free           74
#                 Large          33
#                 Small          13
#                 Extra large     4
# Name: count, dtype: int64

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# Which of the following pair of “Style” and “Price” category has the highest average of positive recommendations?
# - Price: medium and style: vintage
# - Price: medium and style: cute
# - Price: very high and style: party
# - Price: low and style: sexy

# %%
# plot the heat map of Style, price and Recommendation.
res=inp0.pivot_table(index='Style', columns='Price', values='Recommendation', aggfunc='mean')
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(res,annot=True,cmap="RdYlGn")
plt.show()
#Price: medium and style: cute

# %% [markdown]
# Which of the following material type has no recommendation in summer and winter seasons?
# - Mix and Milksilk
# - Nylon and Rayon
# - Microfiber and Silk
# - Milksilk and Microfiber

# %%
# plot the heat map of Season, material and Recommendation.
res=inp0.pivot_table(index='Season', columns='Material', values='Recommendation', aggfunc='mean')
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(res,annot=True,cmap="RdYlGn")
plt.show()
'''' Microfiber and Silk
Milksilk and Microfiber'''

# %%
options = {
    "Mix and Milksilk": ["Mix", "Milksilk"],
    "Nylon and Rayon": ["Nylon", "Rayon"],
    "Microfiber and Silk": ["Microfiber", "Silk"],
    "Milksilk and Microfiber": ["Milksilk", "Microfiber"]
}

# Check which pair's materials are both in the no_recs_in_both list
for option, materials in options.items():
    if all(mat in no_recs_in_both for mat in materials):
        print(f"✅ Correct answer: {option}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-a8d9e5abd8d7> in <cell line: 0>()
#       8 # Check which pair's materials are both in the no_recs_in_both list
#       9 for option, materials in options.items():
# ---> 10     if all(mat in no_recs_in_both for mat in materials):
#      11         print(f"✅ Correct answer: {option}")
#
# <ipython-input-51-a8d9e5abd8d7> in <genexpr>(.0)
#       8 # Check which pair's materials are both in the no_recs_in_both list
#       9 for option, materials in options.items():
# ---> 10     if all(mat in no_recs_in_both for mat in materials):
#      11         print(f"✅ Correct answer: {option}")
#
# NameError: name 'no_recs_in_both' is not defined

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   O-neck   Sleeveless
# 1  1212192089   Casual      Low     0.0   Large  Summer   O-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   O-neck  Full-Sleeve
# 3   966005983    Brief  Average     4.6   Large  Spring   O-neck  Full-Sleeve
# 4   876339541     cute      Low     4.5  Medium  Summer   O-neck       Others
#
#         Material FabricType  Decoration Pattern Type  Recommendation   Summer  \
# 0         cotton    Chiffon     ruffles       animal               1  17822.0
# 1     microfiber    Chiffon     ruffles       animal               0  10240.0
# 2       polyster    Chiffon     ruffles        print               0     51.0
# 3           silk    Chiffon  embroidary        print               1   9168.0
# 4  chiffonfabric    Chiffon         bow          dot               0  10320.0
#
#     Winter  Spring   Autumn
# ...
